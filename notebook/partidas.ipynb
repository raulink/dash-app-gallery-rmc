# %%
import os
os.listdir('data')
# Out:
# ['Partidas_20240826.120509.xlsx']

# %%
import pandas as pd

df = pd.read_excel('data/Partidas_20240826.120509.xlsx')
df
# Out:
#      Nro.  Código Clasificación  \
# 0       1   10000      PERSONAL
# 1       2   11000      PERSONAL
# 2       3   11100      PERSONAL
# 3       4   11210      PERSONAL
# 4       5   11220      PERSONAL
# ..    ...     ...           ...
# 418   419   98200         OTROS
# 419   420   98300           NaN
# 420   421   99000         OTROS
# 421   422   99100         OTROS
# 422   423   99200         OTROS
#
#                                          Descripción  \
# 0                               SERVICIOS PERSONALES
# 1                              EMPLEADOS PERMANENTES
# 2                                    HABERES BASICOS
# 3                              CATEGORIAS MAGISTERIO
# 4                                 BONO DE ANTIGUEDAD
# ..                                               ...
# 418                               DEL SECTOR PRIVADO
# 419                               PAGO DE DIVIDENDOS
# 420  PROVISIONES PARA GASTOS CORRIENTES Y DE CAPITAL
# ...
